# %% [markdown]
# ### Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv(r"C:\Users\USER\Downloads\exchange_rate.csv",parse_dates=True ) #Parse_dates- reads dates as dates only
print(df.head())
print(df.dtypes)
print(df.shape)
print(df.isnull().sum())
df.plot() #Line chart
plt.title('USD to AUD Exchange Rate Over Time')
plt.xlabel('Date')
plt.ylabel('Exchange Rate')
plt.legend()
plt.show()
# Out:
#                date  Ex_rate
# 0  01-01-1990 00:00   0.7855
# 1  02-01-1990 00:00   0.7818
# 2  03-01-1990 00:00   0.7867
# 3  04-01-1990 00:00   0.7860
# 4  05-01-1990 00:00   0.7849
# date        object
# Ex_rate    float64
# dtype: object
# (7588, 2)
# date       0
# Ex_rate    0
# dtype: int64

# %% [raw]
# The presence of a trend suggests the series is non-stationary.

# %%
#Set date as index
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y %H:%M')
df.set_index('date', inplace=True) 
print(df.index)
df = df.sort_index()
ts = df['Ex_rate']
df.head()# time series column
# Out:
# DatetimeIndex(['1990-01-01', '1990-01-02', '1990-01-03', '1990-01-04',
#                '1990-01-05', '1990-01-06', '1990-01-07', '1990-01-08',
#                '1990-01-09', '1990-01-10',
#                ...
#                '2010-10-01', '2010-10-02', '2010-10-03', '2010-10-04',
#                '2010-10-05', '2010-10-06', '2010-10-07', '2010-10-08',
#                '2010-10-09', '2010-10-10'],
#               dtype='datetime64[ns]', name='date', length=7588, freq=None)
#             Ex_rate
# date
# 1990-01-01   0.7855
# 1990-01-02   0.7818
# 1990-01-03   0.7867
# 1990-01-04   0.7860
# 1990-01-05   0.7849

# %% [markdown]
# #### ADFuller test

# %%
#To know whether plot is stationary or not - ADFuller test
#H0- Process is non-stationary
#H1- Process is stationary

from statsmodels.tsa.stattools import adfuller

result = adfuller(ts)
print("ADF Statistic:", result[0])
print("p-value:", result[1])
print('Critical values', result[4])
# Out:
# ADF Statistic: -1.664994180738078
# p-value: 0.44923273535982894
# Critical values {'1%': np.float64(-3.4312123140180137), '5%': np.float64(-2.861921078147796), '10%': np.float64(-2.5669728434336108)}

# %% [raw]
# p-value>alpha(0.05), p ≥ 0.05 → NOT stationary → difference

# %%
#Apply differencing
ts_diff = ts.diff().dropna()
adf_test(ts_diff)
# Out:
# {'ADF Statistic': np.float64(-99.39343120118623),
#  'p-value': 0.0,
#  'Critical values': {'1%': np.float64(-3.4312123140180137),
#   '5%': np.float64(-2.861921078147796),
#   '10%': np.float64(-2.5669728434336108)}}

# %% [markdown]
# ##### Parameter Selection for ARIMA

# %%
#d = 1
# Plot ACF and PACF for parameter estimation
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf  

plt.figure(figsize=(12,5))
plt.title("Before Differencing", fontsize=20)
plt.subplot(121)
plot_acf(ts, lags=30, ax=plt.gca())
plt.subplot(122)
plot_pacf(ts, lags=30, ax=plt.gca())
plt.show()

# %%
#d = 1
# Plot ACF and PACF for parameter estimation
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf  

plt.figure(figsize=(12,5))
plt.title("After Differencing", fontsize=20)
plt.subplot(121)
plot_acf(ts_diff, lags=30, ax=plt.gca())
plt.subplot(122)
plot_pacf(ts_diff, lags=30, ax=plt.gca())
plt.show()

# %%
#Data split
ts = df["Ex_rate"]

train_size = int(len(ts) * 0.8)
train, test = ts[:train_size], ts[train_size:]

# %% [markdown]
# #### Build ARIMA model

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.arima.model import ARIMA


# Fit ARIMA model
model = ARIMA(train, order=(1,1,1))
model_fit = model.fit()

# Forecast
forecast_arima = model_fit.forecast(steps=len(test))

# Evaluation metrics (version-safe)
mae = mean_absolute_error(test, forecast_test)
rmse = np.sqrt(mean_squared_error(test, forecast_test))
mape = np.mean(np.abs((test - forecast_test) / test)) * 100

print(f"MAE  : {mae:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"MAPE : {mape:.2f}%")

# Plot
plt.figure(figsize=(12,6))
plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, label='Actual Test')
plt.plot(test.index, forecast_test, label='Forecast', color='red')
plt.title('ARIMA Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\USER\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\USER\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# MAE  : 0.1777
# RMSE : 0.2054
# MAPE : 22.80%

# %%
# Residuals
residuals = arima_model_fit.resid

plt.figure(figsize=(12,6))
plt.subplot(121)
residuals.plot(title='Residuals', ax=plt.gca())
plt.subplot(122)
residuals.plot(kind='kde', title='Density', ax=plt.gca())
plt.show()

# ACF of residuals to check for remaining autocorrelation
plot_acf(residuals, lags=30)
plt.show()

# %%
#Exponential Smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

model_es = ExponentialSmoothing(
    train,
    trend='add',
    seasonal=None
)

es_fit = model_es.fit()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
forecast_es = es_fit.forecast(steps=len(test))


plt.figure(figsize=(10,5))
plt.plot(df, label='Actual')
plt.plot(forecast, label='Forecast', color='red')
plt.legend()
plt.show()

# %%
#Evaluation
#ARIMA model and ExponentialSmoothing model

# Error metrics
#Evaluation metrics
def evaluate(actual, predicted):
    mae = mean_absolute_error(actual, predicted)
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    mape = np.mean(np.abs((actual - predicted) / actual)) * 100
    return mae, rmse, mape


arima_mae, arima_rmse, arima_mape = evaluate(test, forecast_arima)
es_mae, es_rmse, es_mape = evaluate(test, forecast_es)

print("ARIMA -> MAE:", arima_mae, "RMSE:", arima_rmse, "MAPE:", arima_mape)
print("ES   -> MAE:", es_mae, "RMSE:", es_rmse, "MAPE:", es_mape)


#Comparing Forecast vs actual (and arima vs es)
plt.figure(figsize=(12,6))
plt.plot(train.index, train, label="Train")
plt.plot(test.index, test, label="Actual")
plt.plot(test.index, forecast_arima, label="ARIMA Forecast", color="red")
plt.plot(test.index, forecast_es, label="ETS Forecast", color="green")
plt.legend()
plt.title("Exchange Rate Forecast Comparison")
plt.show()
# Out:
# ARIMA -> MAE: 0.1777097044912133 RMSE: 0.20543669659669261 MAPE: 22.79796617381153
# ES   -> MAE: 0.20659619216588007 RMSE: 0.23910443281197072 MAPE: 26.508663930344888

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

def metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = np.mean(np.abs((y_true - y_pred)/y_true)) * 100
    return mae, rmse, mape

print("ARIMA:", metrics(test, forecast_arima))
print("Exp Smoothing:", metrics(test, forecast_es))
# Out:
# ARIMA: (0.1777097044912133, np.float64(0.20543669659669261), np.float64(22.79796617381153))
# Exp Smoothing: (0.20659619216588007, np.float64(0.23910443281197072), np.float64(26.508663930344888))

# %% [raw]
# Performance, Advantages, and Limitations
#
# The ARIMA model demonstrated superior performance compared to Exponential Smoothing (ES) for forecasting this exchange rate dataset. The evaluation metrics — MAE: 0.178, RMSE: 0.205, MAPE: 22.8% — indicate that ARIMA was able to capture the underlying patterns and autocorrelations in the data more effectively than ES. ARIMA’s ability to incorporate autoregressive and moving average components allows it to model both trend and short-term dependencies, which is particularly beneficial for time series that exhibit non-stationarity, as seen in this dataset. This flexibility makes ARIMA well-suited for financial data like exchange rates, which often contain trends and random fluctuations.
#
# On the other hand, Exponential Smoothing yielded slightly higher errors — MAE: 0.207, RMSE: 0.239, MAPE: 26.5% — suggesting that while it is capable of smoothing out noise and capturing simple trends, it struggled to account for the more complex autocorrelations present in the series. ES is advantageous for its simplicity and computational efficiency, making it easy to implement and interpret. However, it is limited in handling series with strong autocorrelation, non-stationarity, or abrupt changes, which are common in financial time series. The observed higher MAPE for ES indicates that its forecasts were comparatively less accurate, particularly in capturing short-term fluctuations.
#
#
#
# Conclusion
#
# In conclusion, based on the observed error metrics, ARIMA outperformed Exponential Smoothing in forecasting the exchange rates in this dataset. Its lower MAE, RMSE, and MAPE demonstrate that it provided more accurate and reliable predictions. While ES remains a viable option for quick, simple forecasting and smoothing tasks, ARIMA’s ability to model trends and autocorrelations makes it a better choice for this type of time series data. Therefore, for exchange rate forecasting in this dataset, ARIMA is the preferred model, though further improvements may be achieved through hyperparameter tuning or considering seasonal extensions like SARIMA.
